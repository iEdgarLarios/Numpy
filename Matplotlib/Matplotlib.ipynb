# %% [markdown]
# # MATPLOTLIB
#
# ### Erika Yunuen Flores Monroy

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
movies = pd.read_csv('movie_metadata.csv', nrows=20, skiprows=[1])

# %%
movies.head(3)
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color     Gore Verbinski                   302.0     169.0
# 1  Color         Sam Mendes                   602.0     148.0
# 2  Color  Christopher Nolan                   813.0     164.0
#
#    director_facebook_likes  actor_3_facebook_likes    actor_2_name  \
# 0                      563                  1000.0   Orlando Bloom
# 1                        0                   161.0    Rory Kinnear
# 2                    22000                 23000.0  Christian Bale
#
#    actor_1_facebook_likes        gross                     genres  ...  \
# 0                   40000  309404152.0   Action|Adventure|Fantasy  ...
# 1                   11000  200074175.0  Action|Adventure|Thriller  ...
# 2                   27000  448130642.0            Action|Thriller  ...
#
#   num_user_for_reviews language  country  content_rating       budget  \
# 0               1238.0  English      USA           PG-13  300000000.0
# ...

# %%
movies.groupby('genres')['movie_facebook_likes'].sum().plot(kind='line', legend='Reverse')

# %%
movies.groupby('genres')['movie_facebook_likes'].sum().plot(kind='pie', legend='Reverse')

# %%
movies.groupby('genres')['movie_facebook_likes'].sum().plot(kind='bar', legend='Reverse')

# %%
y = movies['duration']
x = movies['genres']

plt.xlabel('genres')
plt.ylabel('duration')
plt.scatter(x,y)

# %%
y = movies['duration']
x = movies['genres']

plt.xlabel('genres')
plt.ylabel('duration')
plt.bar(x,y)
# Out:
# <BarContainer object of 20 artists>

# %%
movies.num_critic_for_reviews.groupby(movies.genres).sum().plot(kind='pie', cmap='Paired')

# %%
movies.num_critic_for_reviews.groupby(movies.genres).sum().plot(kind='bar', cmap='Paired')

# %%
movies.num_critic_for_reviews.groupby(movies.genres).sum().plot(kind='line', cmap='Paired')
